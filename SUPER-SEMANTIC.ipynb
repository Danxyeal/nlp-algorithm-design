# %%
from bs4 import BeautifulSoup
import pprint

def get(file):
    with open(file, 'r') as html_file:
        lines = html_file.readlines()
        return [l.replace('\n','') for l in lines]
 
def quieten(text):
    # for ch in ['\\','`','*','_','{','}','[',']','(',')','>','#','+','-','.','!','$','\'']:
    quiet_text = str(text)
    quiet_text = quiet_text.replace('[','')
    quiet_text = quiet_text.replace(']','')
    quiet_text = quiet_text.replace('}','')
    quiet_text = quiet_text.replace('{','')
    quiet_text = quiet_text.replace('\'','')
    quiet_text = quiet_text.replace('\"','')
    return quiet_text 

def soup_lines(lines):
    for text in lines:
        return (BeautifulSoup(text, 'html.parser') for text in lines)

# List comprehensions getting parts from the beautifulsoup object instances
read_tags = lambda soup: [tag.name for tag in soup.find_all()]
read_attrs = lambda soup: [tag.attrs for tag in soup.find_all() if not tag.attrs == {}]
read_text = lambda soup: [tag.text for tag in soup.find_all()]

def join_tag_to_attrs(tag, attrs):
    ats = attrs.items()
    print(tag, list(ats)[0])

def join_parts(tags, attrs, text):
    tag_attrs = ''
    if tags and attrs:
        for i in range(0,len(tags)):
            tag_attrs = join_tag_to_attrs(tags[i], attrs[i])
    return ['-'.join(tags), attrs, text] 
            
def destructure_noisy_html(html_lines):

    lines = [line.replace('\t','') for line in html_lines]
    tags = [read_tags(soup) for soup in soup_lines(lines)]
    attrs = [read_attrs(soup) for soup in soup_lines(lines)]
    text = [soup.text for soup in soup_lines(lines)]
    return (list(map(join_parts, tags, attrs, text)))

def test():
    noisy_html = get('specs-chunk.html')
    less_noisy = destructure_noisy_html(noisy_html)
    pp = pprint.PrettyPrinter(indent=4)
    #pp.pprint(less_noisy)

test()
# Out:
# div ('id', 'prodDetails')
# div ('class', ['a-row', 'a-spacing-top-base'])
# div ('class', ['a-column', 'a-span6'])
# div ('class', ['a-row', 'a-spacing-base'])
# div ('aria-live', 'polite')
# div ('class', ['a-row'])
# div ('class', ['a-column', 'a-span6'])
# h1 ('class', ['a-size-medium', 'a-spacing-small'])
# a ('href', 'javascript:void(0)')
# i ('class', ['a-icon', 'a-icon-extender-collapse'])
# span ('class', ['a-expander-prompt'])
# div ('aria-expanded', 'true')
# div ('aria-live', 'polite')
# div ('class', ['a-row'])
# span ('class', ['a-declarative'])
# a ('href', 'javascript:void(0)')
# i ('class', ['a-icon', 'a-icon-collapse'])
# span ('class', ['a-expander-prompt'])
# div ('aria-expanded', 'true')
# table ('id', 'productDetails_techSpec_section_1')
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# div ('aria-live', 'polite')
# div ('class', ['a-row'])
# span ('class', ['a-declarative'])
# a ('href', 'javascript:void(0)')
# i ('class', ['a-icon', 'a-icon-collapse'])
# span ('class', ['a-expander-prompt'])
# div ('aria-expanded', 'true')
# table ('id', 'productDetails_techSpec_section_2')
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# div ('class', ['a-row', 'a-spacing-base'])
# div ('class', ['a-row'])
# script ('type', 'text/javascript')
# div ('class', ['a-column', 'a-span6', 'a-span-last'])
# div ('class', ['a-row', 'a-spacing-base'])
# div ('id', 'productDetails_db_sections')
# h1 ('class', ['a-size-medium', 'a-spacing-small', 'secHeader'])
# div ('class', ['a-section', 'table-padding'])
# table ('id', 'productDetails_detailBullets_sections1')
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# td ('class', ['a-size-base'])
# style ('type', 'text/css')
# div ('id', 'averageCustomerReviews')
# span ('class', ['a-declarative'])
# span ('id', 'acrPopover')
# span ('class', ['a-declarative'])
# a ('href', 'javascript:void(0)')
# i ('class', ['a-icon', 'a-icon-star', 'a-star-5'])
# span ('class', ['a-icon-alt'])
# i ('class', ['a-icon', 'a-icon-popover'])
# span ('class', ['a-letter-space'])
# span ('class', ['a-letter-space'])
# span ('class', ['a-declarative'])
# a ('id', 'acrCustomerReviewLink')
# span ('id', 'acrCustomerReviewText')
# script ('type', 'text/javascript')
# script ('type', 'text/javascript')
# th ('class', ['a-color-secondary', 'a-size-base', 'prodDetSectionEntry'])
# span ('href', '/gp/bestsellers/computers/ref=pd_zg_ts_computers')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-f521640148ea> in <module>
#      52     #pp.pprint(less_noisy)
#      53
# ---> 54 test()
#
# <ipython-input-2-f521640148ea> in test()
#      48 def test():
#      49     noisy_html = get('specs-chunk.html')
# ---> 50     less_noisy = destructure_noisy_html(noisy_html)
#      51     pp = pprint.PrettyPrinter(indent=4)
#      52     #pp.pprint(less_noisy)
#
# <ipython-input-2-f521640148ea> in destructure_noisy_html(html_lines)
#      44     attrs = [read_attrs(soup) for soup in soup_lines(lines)]
#      45     text = [soup.text for soup in soup_lines(lines)]
# ---> 46     return (list(map(join_parts, tags, attrs, text)))
#      47
#      48 def test():
#
# <ipython-input-2-f521640148ea> in join_parts(tags, attrs, text)
#      35     if tags and attrs:
#      36         for i in range(0,len(tags)):
# ---> 37             tag_attrs = join_tag_to_attrs(tags[i], attrs[i])
#      38     return ['-'.join(tags), attrs, text]
#      39
#
# IndexError: list index out of range

# %%
def semify(line):
    if not line[0]:
        line[0] = None
    else:
        line[0] = line[0].replace('div','divider')
        line[0] = line[0].replace('h2','heading')
        line[0] = line[0].replace('p','paragraph')
    if len(line[1]) < 1:
        line[1] = None
    return line

def main():
    noisy_html = get('specs-chunk.html')
    less_noisy = destructure_noisy_html(noisy_html)
    semantic = [semify(line) for line in less_noisy]
    # quieter = [quieten(line) for line in semantic] 
    quieter = semantic
    pp = pprint.PrettyPrinter(indent=4)
    #pp.pprint(quieter)

if __name__ == ('__main__'):
    main()
