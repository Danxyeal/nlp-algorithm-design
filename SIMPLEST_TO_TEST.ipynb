# %%
'''Form a list of strings from HTML text-content and structure

Functional style solution to simplify the HTML
DOM tree of any chunk of HTML. Higher-order Functions,
Lambdas, Closure, and List Comprehensions are used.

This algorithm focuses on extracting text content
while retaining basic structural relationships
from the HTML as semantic structural units
of natural language.

IN:  HTML Chunk or Whole document
OUT: List of HTML lines destructured
'''
from bs4 import BeautifulSoup
import pprint

def get(file):
    '''Get HTML file from path
    
    PARAM: str - Path to file
    RETURNS: html/txt file as Python List of lines
    '''
    with open(file, 'r') as html_file:
        lines = html_file.readlines()
        return [l.replace('\n','') for l in lines]
    
def soup_lines(lines):
    '''Make beautiful soup object instances from HTML lines

    PARAM: List of html lines in a list
    RETURNS: List of beautifulsoup instances'''
    for text in lines:
        return (BeautifulSoup(text, 'lxml') for text in lines)

# List comprehensions getting parts from the beautifulsoup object instances
read_tags = lambda soup: [tag.name for tag in soup.find_all()]
read_attrs = lambda soup: [tag.attrs for tag in soup.find_all() if not tag.attrs == {}]
read_text = lambda soup: [tag.text for tag in soup.find_all()]

def join_parts(tag, attr, text):
    return {','.join(tag): attr, 'raw text': text}
                
# This is done by another class in the codebase but here it is expecting
# to receive the body only or just the div that holds the product info.
def destructure_noisy_html(html_lines):
    # Split noisy HTML chunk into lines keeping natural order
    # And hold as Beautiful Soup object instances (1 per line)
    # Important: KEEPS HTML DOCUMENT ORDER
    # Do a series of List Comprehensions:
    # Remove tabs
    lines = [line.replace('\t','') for line in html_lines]
    # Create list: HTML_TAGS
    tags = [read_tags(soup) for soup in soup_lines(lines)]
    # Create list: HTML_ATTRIBUTES as dictionary-like
    attrs = [read_attrs(soup) for soup in soup_lines(lines)]
    # Create list: TEXT string from HTML content
    #text = [read_text(soup) for soup in soup_lines(lines)]
    text = [soup.text for soup in soup_lines(lines)]
    # Create quiet list: STRINGS of 3 above lists
    return (list(map(join_parts, tags, attrs, text)))

'''def join_text_lines(lines):
    for i in range(0, len(lines)):
        if lines[i]['raw text'] and lines[i]['']:'''
            

if __name__ == ('__main__'):
    noisy_html = get('specs-chunk.html')
    less_noisy = destructure_noisy_html(noisy_html)
    quieter = [line for line in less_noisy if not line == ', [], '] 
    #impler = join_text_lines(quieter)
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(quieter)
# Out:
# [   {   'html,body,div': [{'class': ['a-section'], 'id': 'prodDetails'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,h2': [], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Product Information'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,span': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [{'class': ['a-row', 'a-spacing-top-base']}],
#         'raw text': ''},
#     {'html,body,div': [{'class': ['a-column', 'a-span6']}], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-row', 'a-spacing-base']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'aria-live': 'polite',
#                                  'class': [   'a-row',
#                                               'a-expander-container',
#                                               'a-expander-extend-container']}],
#         'raw text': ''},
#     {'html,body,div': [{'class': ['a-row']}], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-column', 'a-span6']}], 'raw text': ''},
#     {   'html,body,h1': [{'class': ['a-size-medium', 'a-spacing-small']}],
#         'raw text': 'Technical Details'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,a,i,span': [   {   'class': [   'a-expander-header',
#                                                    'a-declarative',
#                                                    'a-expander-extend-header',
#                                                    'prodDet-expander-header'],
#                                       'data-a-expander-toggle': '{"allowLinkDefault":true, '
#                                                                 '"expand_prompt":"Expand '
#                                                                 'all", '
#                                                                 '"collapse_prompt":"Collapse '
#                                                                 'all"}',
#                                       'data-action': 'a-expander-toggle',
#                                       'href': 'javascript:void(0)'},
#                                   {   'class': [   'a-icon',
#                                                    'a-icon-extender-collapse']},
#                                   {'class': ['a-expander-prompt']}],
#         'raw text': 'Collapse all'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'aria-expanded': 'true',
#                                  'class': [   'a-expander-content',
#                                               'a-expander-extend-content'],
#                                  'style': 'overflow: hidden; display: block;'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'aria-live': 'polite',
#                                  'class': [   'a-row',
#                                               'a-expander-container',
#                                               'a-expander-inline-container']}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-row']}], 'raw text': ''},
#     {   'html,body,span': [   {   'class': ['a-declarative'],
#                                   'data-action': 'mySummaryExpander_1',
#                                   'data-mysummaryexpander_1': '{}'}],
#         'raw text': ''},
#     {   'html,body,a,i,span': [   {   'class': [   'a-expander-header',
#                                                    'a-declarative',
#                                                    'a-expander-inline-header',
#                                                    'prodDet-heading-alignment',
#                                                    'a-link-expander'],
#                                       'data-a-expander-toggle': '{"allowLinkDefault":true, '
#                                                                 '"expand_prompt":"", '
#                                                                 '"collapse_prompt":""}',
#                                       'data-action': 'a-expander-toggle',
#                                       'href': 'javascript:void(0)'},
#                                   {'class': ['a-icon', 'a-icon-collapse']},
#                                   {'class': ['a-expander-prompt']}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Summary'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'aria-expanded': 'true',
#                                  'class': [   'a-expander-content',
#                                               'a-expander-section-content',
#                                               'a-section-expander-inner']}],
#         'raw text': ''},
#     {   'html,body,table': [   {   'class': ['a-keyvalue', 'prodDetTable'],
#                                    'id': 'productDetails_techSpec_section_1',
#                                    'role': 'presentation'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tbody,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Standing screen display size'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '14 Centimeters'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Max Screen Resolution'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '1920x1080 Pixels'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Graphics Coprocessor'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Intel HD Graphics 615'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Chipset Brand'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Intel'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Card Description'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Integrated'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Wireless Type'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '801.11ac'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Number of USB 3.0 Ports'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '1'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Average Battery Life (in hours)'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '8 Hours'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'aria-live': 'polite',
#                                  'class': [   'a-row',
#                                               'a-expander-container',
#                                               'a-expander-inline-container']}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-row']}], 'raw text': ''},
#     {   'html,body,span': [   {   'class': ['a-declarative'],
#                                   'data-action': 'mySummaryExpander_2',
#                                   'data-mysummaryexpander_2': '{}'}],
#         'raw text': ''},
#     {   'html,body,a,i,span': [   {   'class': [   'a-expander-header',
#                                                    'a-declarative',
#                                                    'a-expander-inline-header',
#                                                    'prodDet-heading-alignment',
#                                                    'a-link-expander'],
#                                       'data-a-expander-toggle': '{"allowLinkDefault":true, '
#                                                                 '"expand_prompt":"", '
#                                                                 '"collapse_prompt":""}',
#                                       'data-action': 'a-expander-toggle',
#                                       'href': 'javascript:void(0)'},
#                                   {'class': ['a-icon', 'a-icon-collapse']},
#                                   {'class': ['a-expander-prompt']}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Other Technical Details'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'aria-expanded': 'true',
#                                  'class': [   'a-expander-content',
#                                               'a-expander-section-content',
#                                               'a-section-expander-inner']}],
#         'raw text': ''},
#     {   'html,body,table': [   {   'class': ['a-keyvalue', 'prodDetTable'],
#                                    'id': 'productDetails_techSpec_section_2',
#                                    'role': 'presentation'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tbody,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Brand'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'ASUS'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Item Model Number'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'C434TA-AI0033'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Operating System'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Chrome OS'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Product Dimensions'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '32.1 x 20.2 x 1.57 cm; 1.45 Kilograms'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Item Dimensions  L x W x H'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '32.1 x 20.2 x 1.6 centimetres'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Colour'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Silver'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Processor Brand'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Intel'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Processor Count'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '2'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Computer Memory Type'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'DDR3 SDRAM'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Flash Memory Size'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '32 GB'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Power Source'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Battery'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Batteries'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {   'html,body,p': [],
#         'raw text': '1 Lithium ion batteries required. (included)'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Item Weight'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '1.45 kg'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-row', 'a-spacing-base']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-row']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,head,script': [{'type': 'text/javascript'}], 'raw text': ''},
#     {   'html,body,p': [],
#         'raw text': "P.when('A', 'ready').execute(function(A) {"},
#     {'html,body,p': [], 'raw text': 'var asin = "";'},
#     {   'html,body,p': [],
#         'raw text': "A.declarative('enhanced-content-open-file', 'click', "
#                     'function(event) {'},
#     {'html,body,p': [], 'raw text': 'var pageAction = event.data;'},
#     {   'html,body,p': [],
#         'raw text': 'window.ue.count("ProductInfo" + pageAction, 1);'},
#     {   'html,body,p': [],
#         'raw text': "A.ajax('/gp/product/ajax-handlers/enhanced-content-popover-metrics.html', "
#                     '{'},
#     {'html,body,p': [], 'raw text': "method: 'post',"},
#     {   'html,body,p': [],
#         'raw text': 'params: {"asin": asin, "pageAction": pageAction}'},
#     {'html,body,p': [], 'raw text': '});'},
#     {'html,body,p': [], 'raw text': '});'},
#     {'html,body,p': [], 'raw text': '});'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [{'class': ['a-column', 'a-span6', 'a-span-last']}],
#         'raw text': ''},
#     {'html,body,div': [{'class': ['a-row', 'a-spacing-base']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'class': ['a-section'],
#                                  'id': 'productDetails_db_sections'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,h1': [   {   'class': [   'a-size-medium',
#                                              'a-spacing-small',
#                                              'secHeader']}],
#         'raw text': 'Additional Information'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [{'class': ['a-section', 'table-padding']}],
#         'raw text': ''},
#     {   'html,body,table': [   {   'class': ['a-keyvalue', 'prodDetTable'],
#                                    'id': 'productDetails_detailBullets_sections1',
#                                    'role': 'presentation'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tbody,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'ASIN'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': 'B086K2B1TG'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': 'Customer Reviews'},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,head,style': [{'type': 'text/css'}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '/*'},
#     {   'html,body,p': [],
#         'raw text': '* Fix for UDP-1061. Average customer reviews has a small '
#                     'extra line on hover'},
#     {   'html,body,p': [],
#         'raw text': '* '
#                     'https://omni-grok.amazon.com/xref/src/appgroup/websiteTemplates/retail/SoftlinesDetailPageAssets/udp-intl-lock/src/legacy.css?indexName=WebsiteTemplates#40'},
#     {'html,body,p': [], 'raw text': '*/'},
#     {'html,body,p': [], 'raw text': '.noUnderline a:hover {'},
#     {'html,body,p': [], 'raw text': 'text-decoration: none;'},
#     {'html,body,p': [], 'raw text': '}'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [   {   'data-asin': 'B086K2B1TG',
#                                  'data-ref': 'dpx_acr_pop_',
#                                  'id': 'averageCustomerReviews'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,span': [   {   'class': ['a-declarative'],
#                                   'data-acrstarslink-click-metrics': '{}',
#                                   'data-action': 'acrStarsLink-click-metrics'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,span': [   {   'class': [   'reviewCountTextLinkedHistogram',
#                                                'noUnderline'],
#                                   'id': 'acrPopover',
#                                   'title': '5.0 out of 5 stars'}],
#         'raw text': ''},
#     {   'html,body,span': [   {   'class': ['a-declarative'],
#                                   'data-a-popover': '{"max-width":"700","closeButton":"false","position":"triggerBottom","url":"/gp/customer-reviews/widgets/average-customer-review/popover/ref=dpx_acr_pop_?contextId=dpx&asin=B086K2B1TG"}',
#                                   'data-action': 'a-popover'}],
#         'raw text': ''},
#     {   'html,body,a': [   {   'class': ['a-popover-trigger', 'a-declarative'],
#                                'href': 'javascript:void(0)'}],
#         'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,i,span': [   {   'class': [   'a-icon',
#                                                  'a-icon-star',
#                                                  'a-star-5']},
#                                 {'class': ['a-icon-alt']}],
#         'raw text': '5.0 out of 5 stars'},
#     {'': [], 'raw text': ''},
#     {'html,body,i': [{'class': ['a-icon', 'a-icon-popover']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,span': [{'class': ['a-letter-space']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,span': [{'class': ['a-letter-space']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,span': [   {   'class': ['a-declarative'],
#                                   'data-acrlink-click-metrics': '{}',
#                                   'data-action': 'acrLink-click-metrics'}],
#         'raw text': ''},
#     {   'html,body,a': [   {   'class': ['a-link-normal'],
#                                'href': '#customerReviews',
#                                'id': 'acrCustomerReviewLink'}],
#         'raw text': ''},
#     {   'html,body,span': [   {   'class': ['a-size-base'],
#                                   'id': 'acrCustomerReviewText'}],
#         'raw text': '3 ratings'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,head,script': [{'type': 'text/javascript'}], 'raw text': ''},
#     {   'html,body,p': [],
#         'raw text': "P.when('A', 'ready').execute(function(A) {"},
#     {   'html,body,p': [],
#         'raw text': "A.declarative('acrLink-click-metrics', 'click', { "
#                     '"allowLinkDefault" : true }, function(event){'},
#     {'html,body,p': [], 'raw text': 'if(window.ue) {'},
#     {   'html,body,p': [],
#         'raw text': 'ue.count("acrLinkClickCount", '
#                     '(ue.count("acrLinkClickCount") || 0) + 1);'},
#     {'html,body,p': [], 'raw text': '}'},
#     {'html,body,p': [], 'raw text': '});'},
#     {'html,body,p': [], 'raw text': '});'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,head,script': [{'type': 'text/javascript'}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': "P.when('A', 'cf').execute(function(A) {"},
#     {   'html,body,p': [],
#         'raw text': "A.declarative('acrStarsLink-click-metrics', 'click', { "
#                     '"allowLinkDefault" : true },  function(event){'},
#     {'html,body,p': [], 'raw text': 'if(window.ue) {'},
#     {   'html,body,p': [],
#         'raw text': 'ue.count("acrStarsLinkWithPopoverClickCount", '
#                     '(ue.count("acrStarsLinkWithPopoverClickCount") || 0) + '
#                     '1);'},
#     {'html,body,p': [], 'raw text': '}'},
#     {'html,body,p': [], 'raw text': '});'},
#     {'html,body,p': [], 'raw text': '});'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,br': [], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '5.0 out of 5 stars'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Best Sellers Rank'},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [], 'raw text': ''},
#     {'html,body,span': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,span,a': [   {   'href': '/gp/bestsellers/computers/ref=pd_zg_ts_computers'}],
#         'raw text': '10,178 in Computers (See Top 100 in Computers)'},
#     {'html,body,br': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,span,a': [   {   'href': '/gp/bestsellers/computers/4913311051/ref=pd_zg_hrsr_computers'}],
#         'raw text': '67 in Laptops'},
#     {'html,body,br': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,tr': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,th': [   {   'class': [   'a-color-secondary',
#                                              'a-size-base',
#                                              'prodDetSectionEntry']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Date First Available'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,td': [{'class': ['a-size-base']}], 'raw text': ''},
#     {'html,body,p': [], 'raw text': '1 April 2020'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-row', 'a-spacing-base']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-section']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,h1': [   {   'class': [   'a-size-medium',
#                                              'a-spacing-small',
#                                              'secHeader']}],
#         'raw text': ''},
#     {'html,body,p': [], 'raw text': 'Warranty & Support'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {   'html,body,div': [{'class': ['a-section', 'table-padding']}],
#         'raw text': ''},
#     {   'html,body,span,span,span,table': [   {'class': ['a-letter-space']},
#                                               {   'class': [   'a-keyvalue',
#                                                                'prodDetTable'],
#                                                   'id': 'productDetails_warranty_support_sections',
#                                                   'role': 'presentation'}],
#         'raw text': 'Amazon.com.au Return Policy:You may return for a full '
#                     'refund for the price you paid within 30 days of delivery '
#                     'any new computer purchased from Amazon that is "dead on '
#                     'arrival", arrives in damaged condition or is still in '
#                     'unopened boxes. Amazon may test or inspect returns. If '
#                     'Amazon finds a customer has misrepresented the condition '
#                     'of a return, Amazon may impose a fee equal to up to 15 '
#                     'percent of the merchandise sales price. Any returned '
#                     'computer that is damaged through customer misuse, missing '
#                     'parts, or in unsellable condition due to customer '
#                     'tampering may result in the customer being charged a '
#                     'restocking fee based on the condition of the computer.  '
#                     'This policy does not restrict or alter any non-excludable '
#                     'statutory consumer protections or rights you may have, '
#                     'including under the Australian Consumer Law.  To view '
#                     'full returns terms including return instructions, '
#                     'merchandise-specific requirements and exclusions see our '
#                     '${hash-get returnsPolicyAnchor}Returns Policy Page. New, '
#                     'used, and refurbished products purchased from Marketplace '
#                     'vendors are subject to the returns policy of the '
#                     'individual vendor.'},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'html,body,div': [{'class': ['a-row']}], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''},
#     {'': [], 'raw text': ''}]
